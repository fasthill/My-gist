# %%
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
import urllib.request

# %%
path = 'https://raw.githubusercontent.com/fasthill/My-gist/main/data/CalifoniaHousingPrices/california.png'

# %%
# retrieve .png file from url, save current directory
urllib.request.urlretrieve(path, 'california.png')
# Out:
# ('california.png', <http.client.HTTPMessage at 0x29670409bb0>)

# %%
# image를 nparray로 변환 mpimg.imread() or plt.imread()
california_img=mpimg.imread(path) # == california_img=plt.imread(path)

# %%
# np.array 데이터를 그림으로 표현
plt.imshow(california_img, extent=[-124.55, -113.80, 32.45, 42.05], alpha=0.5, cmap=plt.get_cmap('jet'))

# %%
path = 'https://raw.githubusercontent.com/fasthill/My-gist/main/data/picture/stinkbug1.jpg'
urllib.request.urlretrieve(path, 'stinkbug1.jpg')
# Out:
# ('stinkbug1.jpg', <http.client.HTTPMessage at 0x2967a544ca0>)

# %%
path = 'https://raw.githubusercontent.com/fasthill/My-gist/main/data/picture/stinkbug.webp'
stinkbug_img = plt.imread(path, format='webp') # np.array로 데이터 변환
# 주의 : format parameter를 지정하지 않을 경우는, default를 png 파일로 인식하기 때문에 에러가 발생. 
# 현재 directory에서 직접 읽을 경우는 extention 형식대로 읽어서 문제가 없음.
# 아래와 같이 두 단계로 진행하는 것과 동일 (1. 현재 폴더에 저장하고, 2. 저장된 파일을 읽는 순서)
'''
urllib.request.urlretrieve(path, 'stinkbug.webp')
stinkbug_img = plt.imread('stinkbug.webp')
'''
plt.imshow(stinkbug_img)

# %%
path = 'https://raw.githubusercontent.com/fasthill/My-gist/main/data/picture/stinkbug1.jpg'
stinkbug_img = mpimg.imread(path, format='jpg') # np.array로 데이터 변환
plt.imshow(stinkbug_img)

# %%
import pandas as pd
import numpy as np
housing =  pd.read_csv(
    'https://raw.githubusercontent.com/fasthill/My-gist/main/data/CalifoniaHousingPrices/housing.csv')

path = 'https://raw.githubusercontent.com/fasthill/My-gist/main/data/CalifoniaHousingPrices/california.png'
california_img=mpimg.imread(path, format='png')
ax = housing.plot(kind="scatter", x="longitude", y="latitude", figsize=(10,7),
                  s=housing['population']/100, label="Population",
                  c="median_house_value", cmap=plt.get_cmap("jet"),
                  colorbar=False, alpha=0.4)
plt.imshow(california_img, extent=[-124.55, -113.80, 32.45, 42.05], alpha=0.5,
           cmap=plt.get_cmap("jet"))
plt.ylabel("Latitude", fontsize=14)
plt.xlabel("Longitude", fontsize=14)

prices = housing["median_house_value"]
tick_values = np.linspace(prices.min(), prices.max(), 11)
cbar = plt.colorbar(ticks=tick_values/prices.max())
cbar.ax.set_yticklabels(["$%dk"%(round(v/1000)) for v in tick_values], fontsize=14)
cbar.set_label('Median House Value', fontsize=16)

plt.legend(fontsize=16)
plt.show()
